# %%
import os

os.chdir("C:/Users/pauab/Universidad/aProgramacion/TFM/Notebooks_Pau/8.OMPA/run/")

# %run ./transsect_0.ipynb
# %run ./transsect_0-Copy1.ipynb
# %run ./transsect_0-Copy2.ipynb
# %run ./transsect_0-Copy3.ipynb
# %run ./transsect_0-Copy4.ipynb
# %run ./transsect_0-Copy5.ipynb
# %run ./transsect_0-Copy6.ipynb
# %run ./transsect_0-Copy7.ipynb
