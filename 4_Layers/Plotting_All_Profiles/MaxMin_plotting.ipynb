# %% [markdown]
# # Applying the 2nd approach to all the profiles - zpau

# %%
#First, some imports
import matplotlib.pyplot as plt

#Now we read the data
from read_CTD import read_CTD
data_dirs = ['C:/Users/Pau/Data/TFM/CTD_proc_files_1mbin/']
data=read_CTD(data_dirs)

#And delete the outliers
from out_outliers import out_outliers
for ncast in data.keys():
    for variable in data[ncast].columns:
        out_outliers(data, ncast, variable)

# %%
#Import the function of the 2nd approach
from maxmin import maxmin_plot

# %%
#Applying the 1st approach to all the profiles with the profiles so exagerated
for ncast in data.keys():
    maxmin_plot(data, ncast, lamb=10000000)
# Out:
# Profile 09 has 2 layers
# Profile 10 has 2 layers
# Profile 11 has 2 layers
# Profile 12 has 3 layers
# Profile 13 has 2 layers
# Profile 14 has 2 layers
# Profile 15 has 3 layers
# Profile 16 has 3 layers
# Profile 17 has 2 layers
# Profile 18 has 5 layers
# Profile 19 has 3 layers
# Profile 20 has 6 layers
# Profile 21 has 2 layers
# Profile 22 has 2 layers
# Profile 23 has 5 layers
# Profile 24 has 3 layers
# Profile 25 has 3 layers
# Profile 26 has 4 layers
# Profile 27 has 4 layers
# Profile 28 has 3 layers
# Profile 29 has 3 layers
# Profile 30 has 4 layers
# Profile 31 has 4 layers
# Profile 32 has 4 layers
# Profile 33 has 3 layers
# Profile 34 has 3 layers
# Profile 35 has 3 layers
# Profile 36 has 3 layers
# Profile 37 has 4 layers
# Profile 38 has 4 layers
# Profile 39 has 4 layers
# Profile 40 has 4 layers
# Profile 41 has 4 layers
# Profile 42 has 4 layers
# Profile 43 has 4 layers
# Profile 44 has 4 layers
# Profile 45 has 3 layers
# Profile 46 has 3 layers
# Profile 47 has 4 layers
