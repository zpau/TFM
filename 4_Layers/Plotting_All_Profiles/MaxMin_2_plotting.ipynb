# %% [markdown]
# # Applying the 3rd approach to all the profiles - zpau

# %%
#First, some imports
import matplotlib.pyplot as plt

#Now we read the data
from read_CTD import read_CTD
data_dirs = ['C:/Users/Pau/Data/TFM/CTD_proc_files_1mbin/']
data=read_CTD(data_dirs)

#And delete the outliers
from out_outliers import out_outliers
for ncast in data.keys():
    for variable in data[ncast].columns:
        out_outliers(data, ncast, variable)

# %%
#Import the function of the 2nd approach
from maxmin import maxmin_2_plot

# %%
#Applying the 3rd approach to all the profiles with the profiles so exagerated
#When there are no layers closer than 50m, the 2nd approach is applied
for ncast in data.keys():
    maxmin_2_plot(data, ncast, lamb=5000000)
# Out:
# C:\Users\Pau\aProgramacion\TFM\Notebooks_Pau\4.Layers\Plotting_All_Profiles\maxmin.py:267: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax0 = plt.subplots(figsize=(5,7))
